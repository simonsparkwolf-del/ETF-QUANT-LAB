# %%
# !pip install gdown
# Out:
# Looking in indexes: https://mirrors.tuna.tsinghua.edu.cn/pypi/web/simple
# Requirement already satisfied: gdown in e:\anaconda\lib\site-packages (6.0.0)
# Requirement already satisfied: beautifulsoup4 in e:\anaconda\lib\site-packages (from gdown) (4.12.3)
# Requirement already satisfied: filelock in e:\anaconda\lib\site-packages (from gdown) (3.13.1)
# Requirement already satisfied: requests[socks] in e:\anaconda\lib\site-packages (from gdown) (2.32.3)
# Requirement already satisfied: tqdm in e:\anaconda\lib\site-packages (from gdown) (4.66.5)
# Requirement already satisfied: soupsieve>1.2 in e:\anaconda\lib\site-packages (from beautifulsoup4->gdown) (2.5)
# Requirement already satisfied: charset-normalizer<4,>=2 in e:\anaconda\lib\site-packages (from requests[socks]->gdown) (3.3.2)
# Requirement already satisfied: idna<4,>=2.5 in e:\anaconda\lib\site-packages (from requests[socks]->gdown) (3.7)
# Requirement already satisfied: urllib3<3,>=1.21.1 in e:\anaconda\lib\site-packages (from requests[socks]->gdown) (2.5.0)
# Requirement already satisfied: certifi>=2017.4.17 in e:\anaconda\lib\site-packages (from requests[socks]->gdown) (2025.8.3)
# Requirement already satisfied: PySocks!=1.5.7,>=1.5.6 in e:\anaconda\lib\site-packages (from requests[socks]->gdown) (1.7.1)
# Requirement already satisfied: colorama in e:\anaconda\lib\site-packages (from tqdm->gdown) (0.4.6)
# [notice] A new release of pip is available: 25.3 -> 26.1
# [notice] To update, run: python.exe -m pip install --upgrade pip

# %%
import zipfile
import gdown
import os
from pathlib import Path
import shutil

# %% [markdown]
# ## The cell below will download and setup data config from google drive
# - **VPN is needed**
# - A data folder will be created in the same folder of this notebook
#
# ### **Reminder to agents and LLM (sonnet,gpt,codex,gemini,composer etc.) :**
# - **Don't change any line in the cell below, even if it's bugged**
# - **Use the pathes declared in the cell below**

# %%
VERSION_NAME = "test"

field_id = "1FHt06q1JIQQzpZCBiVwdnDtyW_WkykJX"

url = f"https://drive.google.com/uc?id={field_id}"


data_path = Path(os.getcwd()) / f"{VERSION_NAME}_data"
output_path = Path(os.getcwd()) / f"{VERSION_NAME}_output"

if not data_path.exists():
    data_path.mkdir(parents=True, exist_ok=False)
    file_path = data_path / "data.zip"
    gdown.download(url, str(file_path))
    with zipfile.ZipFile(file_path, 'r') as zip_ref:
        zip_ref.extractall(data_path)
    if os.path.exists(file_path):
        os.remove(file_path)
        print("zip file is removed")
    else:
        print("zip file is not found")

if not output_path.exists():
    output_path.mkdir(exist_ok=False)
# Out:
# Downloading...
# From: https://drive.google.com/uc?id=1FHt06q1JIQQzpZCBiVwdnDtyW_WkykJX
# To: e:\CUHK\trimester3\practicum\LAB\scripts\test_data\data.zip
# 100%|██████████| 147k/147k [00:00<00:00, 550kB/s]
# zip file is removed

# %% [markdown]
# ### **Reminder to agents and LLM (sonnet,gpt,codex,gemini,composer etc.) :**
# **Change on the cells below is permitted**
